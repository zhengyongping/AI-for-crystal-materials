# %% [markdown]
# <a href="https://colab.research.google.com/github/zhengyongping/AI-for-crystal-materials/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = "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" # Replace with your OpenRouter API key
SERPAPI_API_KEY = "8f34c7ccffc310cf3564a988c10a0c4e58962db30b921a751f6f39f4ad7e9a2a" # Replace with your SERPAPI API key
JINA_API_KEY = "jina_fac22ed9480b4958ab34e85b443f5da6DNsbdW1C3Jz6383otpRGN1aMY3w3" # Replace with your JINA API key

# Endpoints
OPENROUTER_URL = "https://openrouter.ai/api/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "anthropic/claude-3.5-haiku"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: magnetsim of graphydine
# Enter maximum number of iterations (default 10): 10
#
# === Iteration 1 ===
# Aggregated 25 unique links from this iteration.
# Fetching content from: https://www.newscientist.com/article/2368771-graphene-shows-record-breaking-magnetic-properties-at-room-temperature/
# Fetching content from: https://www.advancedsciencenews.com/graphene-gets-a-magnetic-boost/
# Fetching content from: https://www.livescience.com/graphene-hides-rare-magnetism.html
# Fetching content from: https://www.nature.com/articles/s41598-020-78262-w
# Fetching content from: https://nanografi.com/blog/is-magnetic-graphene-possible/?srsltid=AfmBOooKckL6aAxSESLHMYyo8Hyq67NhNWr6If2LYJ86BPAFK-jx1koi
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2211379721005295
# Fetching content from: https://www.cam.ac.uk/research/news/magnetic-graphene-forms-a-new-kind-of-magnetism
# Fetching content from: https://pubs.rsc.org/en/content/articlelanding/2012/sc/c1sc00726b
# Fetching content from: https://pubs.rsc.org/en/content/articlelanding/2017/ra/c7ra08917a
# Fetching content from: https://nanografi.com/blog/is-magnetic-graphene-possible/?srsltid=AfmBOookY0avTDyHa4TefzeD5KUwc4PdXP0SyBm2F3wh3PmZ2t_KaRiv
# Fetching content from: https://arxiv.org/pdf/0807.1791
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0079642524000203
# Fetching content from: https://www.nature.com/articles/s41598-020-63478-7
# Fetching content from: https://www.sciencedirect.com/science/article/pii/B9780081021545000059
# Fetching content from: https://phys.org/news/2015-01-magnetic-graphene.html
# Fetching content from: https://www.nature.com/articles/s41535-017-0010-2
# Fetching content from: https://news.ucsc.edu/2023/03/quantum-sensor.html
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0038109820305949
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2238785421001198
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevB.87.205434
# Fetching content from: https://arxiv.org/abs/1301.7138
# Fetching content from: https://pubs.acs.org/doi/10.1021/acs.jpcc.5b09882
# Fetching content from: https://www.researchgate.net/publication/235357266_Magnetic_properties_of_graphene_quantum_dots
# Fetching content from: http://ui.adsabs.harvard.edu/abs/2013PhRvB..87t5434E/abstract
# Fetching content from: https://nanografi.com/blog/is-magnetic-graphene-possible/?srsltid=AfmBOopjfPx4cwvB6fvhqiAbOF7YcdQwoy-Qfdf9cNDt2Gx-PvrvNh5C
# Jina fetch error for https://arxiv.org/pdf/0807.1791: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://news.ucsc.edu/2023/03/quantum-sensor.html: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S0079642524000203: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/s41598-020-63478-7: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://nanografi.com/blog/is-magnetic-graphene-possible/?srsltid=AfmBOooKckL6aAxSESLHMYyo8Hyq67NhNWr6If2LYJ86BPAFK-jx1koi: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S2238785421001198: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/s41535-017-0010-2: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S0038109820305949: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/s41598-020-78262-w: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://link.aps.org/doi/10.1103/PhysRevB.87.205434: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubs.rsc.org/en/content/articlelanding/2017/ra/c7ra08917a: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www
 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['magnetsim computational methods for graphydine', 'advanced numerical modeling graphydine magnetic simulation techniques', 'quantum magnetism computational approaches graphydine', 'graphydine magnetic simulation software and tools']
#
# === Iteration 10 ===
# Aggregated 38 unique links from this iteration.
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0009261412006355
# Fetching content from: https://pubs.acs.org/doi/10.1021/acsomega.1c07136
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S1386947720316325
# Fetching content from: https://wires.onlinelibrary.wiley.com/doi/10.1002/wcms.1545
# Fetching content from: https://arxiv.org/html/2501.10801v1
# Fetching content from: https://www.nature.com/articles/srep12322
# Fetching content from: https://pubs.aip.org/aip/apr/article/11/4/041409/3317501/On-the-study-of-proximity-magnetism-in-van-der
# Fetching content from: https://pubmed.ncbi.nlm.nih.gov/39387114/
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevB.99.224412
# Fetching content from: https://pubs.acs.org/doi/10.1021/jp2121609
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2772571524000585
# Fetching content from: https://www.mdpi.com/2304-6732/10/7/712
# Fetching content from: https://www.researchgate.net/publication/266910299_Advanced_Numerical_Modelling
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevB.89.245404
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0927796X24001190
# Fetching content from: https://www.comsol.com/blogs/micromagnetic-simulation-with-comsol-multiphysics
# Fetching content from: https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne
# Fetching content from: https://coupled2025.cimne.com/event/area/3bbdfc98-70ff-11ef-bbc6-000c29ddfc0c
# Fetching content from: https://www.nature.com/articles/s41598-017-11698-9
# Fetching content from: https://ui.adsabs.harvard.edu/abs/2001PhDT.......123D/abstract
# Fetching content from: https://thequantuminsider.com/2024/02/26/mit-researchers-graphene-advances-could-lead-to-more-robust-quantum-computing/
# Fetching content from: https://www.azoquantum.com/News.aspx?newsID=10263
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC9419551/
# Fetching content from: https://www.cecam.org/workshop-details/computational-materials-discovery-of-unconventional-magnets-14
# Fetching content from: https://www.nature.com/articles/s44306-024-00011-w
# Fetching content from: https://arxiv.org/html/2406.12136v1
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevResearch.2.043437
# Fetching content from: https://news.mit.edu/2015/quantum-materials-new-paradigm-computing-1106
# Fetching content from: https://www.3ds.com/products/simulia/electromagnetic-simulation
# Fetching content from: https://www.3ds.com/products/simulia/electromagnetic-simulation/low-frequency
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2666978123000193
# Fetching content from: https://plm.sw.siemens.com/en-US/simcenter/electromagnetics-simulation/magnet/?srsltid=AfmBOoq-Qhib5DnBc5Rgf7wCCqGnR4KBkUr4ecxl5GcedVMnIa1w70ja
# Fetching content from: https://www.researchgate.net/post/Can-anyone-suggest-any-open-source-software-tool-to-work-on-Graphene
# Fetching content from: https://sourceforge.net/directory/?q=3d%20magnetic%20field%20simulation
# Fetching content from: https://www.comsol.com/blogs/computational-electromagnetics-modeling-which-module-to-use
# Fetching content from: https://www.youtube.com/watch?v=gOieLiDUlRQ
# Fetching content from: https://www.emworks.com/en/
# Jina fetch error for https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://thequantuminsider.com/2024/02/26/mit-researchers-graphene-advances-could-lead-to-more-robust-quantum-computing/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.3ds.com/products/simulia/electromagnetic-simulation/low-frequency: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://plm.sw.siemens.com/en-US/simcenter/electromagnetics-simulation/magnet/?srsltid=AfmBOoq-Qhib5DnBc5Rgf7wCCqGnR4KBkUr4ecxl5GcedVMnIa1w70ja: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://arxiv.org/html/2406.12136v1: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://link.aps.org/doi/10.1103/PhysRevB.99.224412: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/srep12322: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.researchgate.net/post/Can-anyone-suggest-any-open-source-software-tool-to-work-on-Graphene: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://sourceforge.net/directory/?q=3d%20magnetic%20field%20simulation: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.mdpi.com/2304-6732/10/7/712: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.comsol.com/blogs/micromagnetic-simulation-with-comsol-multiphysics: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://link.aps.org/doi/10.1103/PhysRevResearch.2.043437: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.emworks.com/en/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.youtube.com/watch?v=gOieLiDUlRQ: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.3ds.com/products/simulia/electromagnetic-simulation: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S2666978123000193: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pmc.ncbi.nlm.nih.gov/articles/PMC9419551/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S0927796X24001190: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://coupled2025.cimne.com/event/area/3bbdfc98-70ff-11ef-bbc6-000c29ddfc0c: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://ui.adsabs.harvard.edu/abs/2001PhDT.......123D/abstract: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubs.acs.org/doi/10.1021/jp2121609: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubs.aip.org/aip/apr/article/11/4/041409/3317501/On-the-study-of-proximity-magnetism-in-van-der: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubmed.ncbi.nlm.nih.gov/39387114/: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/abs/pii/S0009261412006355: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://link.aps.org/doi/10.1103/PhysRevB.89.245404: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.comsol.com/blogs/computational-electromagnetics-modeling-which-module-to-use: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/s41598-017-11698-9: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.researchgate.net/publication/266910299_Advanced_Numerical_Modelling: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.nature.com/articles/s44306-024-00011-w: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.azoquantum.com/News.aspx?newsID=10263: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/abs/pii/S1386947720316325: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.sciencedirect.com/science/article/pii/S2772571524000585: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://arxiv.org/html/2501.10801v1: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://news.mit.edu/2015/quantum-materials-new-paradigm-computing-1106: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://pubs.acs.org/doi/10.1021/acsomega.1c07136: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# Jina fetch error for https://www.cecam.org/workshop-details/computational-materials-discovery-of-unconventional-magnets-14: 503 - Service Unavailable
# Jina fetch error for https://wires.onlinelibrary.wiley.com/doi/10.1002/wcms.1545: 401 - {"data":null,"code":401,"name":"AuthenticationFailedError","status":40102,"message":"Invalid bearer token","readableMessage":"AuthenticationFailedError: Invalid bearer token"}
# No useful contexts were found in this iteration.
# LLM provided new search queries: ['magnetsim computational techniques graphydine details', 'graphydine magnetic simulation software specifications', 'numerical methods for magnetsim in graphydine research', 'advanced computational magnetism modeling graphydine techniques']
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# I apologize, but I cannot find any relevant contexts or information for the query "magnetsim of graphydine" in the provided text. The query itself seems unusual or potentially misspelled. Without clear context or additional information, I cannot construct a meaningful report.
#
# To help me provide an accurate response, I recommend:
# 1. Clarifying the exact term or concept you're asking about
# 2. Providing correct spelling or additional context
# 3. Specifying the field of study or specific details you're seeking information about
#
# If you can provide more details or clarify the query, I'll be happy to assist you in creating a comprehensive report.
