# %% [markdown]
# <a href="https://colab.research.google.com/github/zhengyongping/AI-for-crystal-materials/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = "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" # Replace with your OpenRouter API key
SERPAPI_API_KEY = "8f34c7ccffc310cf3564a988c10a0c4e58962db30b921a751f6f39f4ad7e9a2a" # Replace with your SERPAPI API key
JINA_API_KEY = "jina_fac22ed9480b4958ab34e85b443f5da6DNsbdW1C3Jz6383otpRGN1aMY3w3" # Replace with your JINA API key

# Endpoints
OPENROUTER_URL = "https://xiaoai.plus/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "anthropic/claude-3.5-haiku"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: graphdiyne magnetism propterties
# Enter maximum number of iterations (default 10): 10
#
# === Iteration 1 ===
# Aggregated 26 unique links from this iteration.
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0925838824039148
# Fetching content from: https://pubs.acs.org/doi/10.1021/acsami.8b03413
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0927025621003219
# Fetching content from: https://pubs.acs.org/doi/10.1021/jp307408u
# Fetching content from: https://link.springer.com/article/10.1007/s12648-023-02798-6
# Fetching content from: https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/
# Fetching content from: https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne
# Fetching content from: https://www.nature.com/articles/s41598-017-11698-9
# Fetching content from: https://link.springer.com/article/10.1007/s40242-021-1350-9
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00675
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00348
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/
# Fetching content from: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5010853
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940
# Fetching content from: https://papers.ssrn.com/sol3/Delivery.cfm/0b93e72a-8265-4ef4-8b3a-06c3ef5521c6-MECA.pdf?abstractid=5010853&mirid=1
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0925963524000499
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0375960123004255
# Fetching content from: https://ui.adsabs.harvard.edu/abs/2023PhLA..48229045L/abstract
# Fetching content from: https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments
# Fetching content from: https://arxiv.org/abs/1207.4380
# Fetching content from: https://www.semanticscholar.org/paper/Review-of-the-Electronic%2C-Optical%2C-and-Magnetic-of-Ge-Chen/adc0fbce8db342877e79acbc3ae9adf3c0d351ce
# Page usefulness for https://pubs.acs.org/doi/10.1021/acsami.8b03413: No
# Page usefulness for https://ui.adsabs.harvard.edu/abs/2023PhLA..48229045L/abstract: Yes
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00675: No
# Page usefulness for https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments: No
# Page usefulness for https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne: No
# Page usefulness for https://arxiv.org/abs/1207.4380: Yes
# Page usefulness for https://www.semanticscholar.org/paper/Review-of-the-Electronic%2C-Optical%2C-and-Magnetic-of-Ge-Chen/adc0fbce8db342877e79acbc3ae9adf3c0d351ce: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219: Yes
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00348: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0925838824039148: Yes
# Page usefulness for https://pubs.acs.org/doi/10.1021/jp307408u: No
# Page usefulness for https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5010853: Yes
# Page usefulness for https://link.springer.com/article/10.1007/s40242-021-1350-9: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350: Yes
# Extracted context from https://ui.adsabs.harvard.edu/abs/2023PhLA..48229045L/abstract (first 200 chars): Based on the research article on graphdiyne magnetism properties, here are the key findings:
#
# Iron (Fen) clusters adsorbed on graphdiyne surface exhibit the following magnetic and electronic character
# Page usefulness for https://link.springer.com/article/10.1007/s12648-023-02798-6: Yes
# Extracted context from https://arxiv.org/abs/1207.4380 (first 200 chars): Here are the key details about graphdiyne's magnetism properties from the research paper:
#
# The study examined the magnetic properties of single transition-metal atoms (V, Cr, Mn, Fe, Co, and Ni) absor
# Page usefulness for https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties: No
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0927025621003219: Yes
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0925838824039148 (first 200 chars): Graphdiyne (GDY) can exhibit magnetic properties when doped with transition metals (Fe, Co, Ni). Key findings include:
#
# - Fe-doped GDY demonstrates a high saturation magnetization of 2.86 emu·g−1 at r
# Page usefulness for https://www.nature.com/articles/s41598-017-11698-9: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0925963524000499: Yes
# Extracted context from https://link.springer.com/article/10.1007/s40242-021-1350-9 (first 200 chars): Based on the provided content, there are no direct discussions about graphdiyne's magnetic properties in this excerpt. The references primarily cover various materials science and chemistry studies re
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/ (first 200 chars): Here are the key findings about graphdiyne magnetism properties:
#
# 1. Graphdiyne can be modified with different light elements (H, F, Cl) to alter its magnetic characteristics
#
# 2. Magnetic properties o
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0375960123004255: Yes
# Extracted context from https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5010853 (first 200 chars): Based on the abstract and content, here are the key details about graphdiyne's magnetic properties:
#
# The study used Monte Carlo simulations and the Ising model to analyze magnetic behavior of graphdiy
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219 (first 200 chars): Here are the key findings about the magnetic properties of graphdiyne from the document:
#
# Graphdiyne (GDY) magnetic properties:
# - Has unique magnetism originating from its sp and sp2 hybridized carbon
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/ (first 200 chars): Based on the content, here are the key points about the magnetic properties of graphdiyne:
#
# The abstract mentions that:
# - Doping and heteroatoms can improve the magnetic properties of graphynes
# - The
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940 (first 200 chars): Relevant information about graphdiyne magnetism properties:
#
# Graphdiyne is a two-dimensional carbon material with unique magnetic characteristics:
#
# 1. Transition metal atom adsorption can produce exce
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350 (first 200 chars): Based on the research paper, here are the key findings about graphdiyne's magnetism properties:
#
# Graphdiyne (GDY) was doped with transition metals (Fe, Co, Ni) to introduce ferromagnetic properties. K
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/ (first 200 chars): Here are the key findings about graphdiyne's magnetic properties from the text:
#
# Graphdiyne can exhibit ferromagnetic properties through strategic chemical doping, particularly with heteroatoms like f
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848 (first 200 chars): Here are the key findings about graphdiyne magnetism properties from the research paper:
#
# Graphdiyne (GDY) Properties:
# - Consists of sp and sp2 hybridized carbon atoms with acetylenic linkages
# - Can b
# Extracted context from https://link.springer.com/article/10.1007/s12648-023-02798-6 (first 200 chars): Based on the abstract and content, here are the key details about graphdiyne's magnetic properties:
#
# 1. The study used Monte Carlo simulation to investigate the magnetic properties of L-graphdiyne wit
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0925963524000499 (first 200 chars): Based on the content, here are the key details about graphdiyne magnetism properties:
#
# Magnetic Properties:
# - Pristine graphdiyne and most transition metal-decorated graphdiyne do not have magnetic pr
# Page usefulness for https://papers.ssrn.com/sol3/Delivery.cfm/0b93e72a-8265-4ef4-8b3a-06c3ef5521c6-MECA.pdf?abstractid=5010853&mirid=1: Yes
# Extracted context from https://www.nature.com/articles/s41598-017-11698-9 (first 200 chars): Here are the key details about graphdiyne's magnetic properties from the research paper:
#
# Magnetic Properties of Pure Graphdiyne:
# - Pure graphdiyne shows typical paramagnetism
# - Has a saturation magne
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0927025621003219 (first 200 chars): Based on the extracted text, here are the key details about graphdiyne's magnetic properties:
#
# Graphdiyne (GDY) exhibits unique magnetic characteristics:
#
# 1. Magnetic sources originate from:
# - Hydroxy
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0375960123004255 (first 200 chars): Here are the key details about graphdiyne's magnetism properties from the research paper:
#
# Magnetic Properties of Graphdiyne:
# - Adding individual 3d metal atoms (Fe, Co, Ni) to graphdiyne can:
#   - Imp
# Extracted context from https://papers.ssrn.com/sol3/Delivery.cfm/0b93e72a-8265-4ef4-8b3a-06c3ef5521c6-MECA.pdf?abstractid=5010853&mirid=1 (first 200 chars): Based on the abstract and content, here are the key insights about graphdiyne's magnetic properties:
#
# The study used Monte Carlo simulations and the Ising model to compare magnetic behaviors of graphe
# LLM provided new search queries: ['graphdiyne magnetic properties theoretical models', 'graphdiyne spintronic applications', 'quantum mechanical modeling of graphdiyne magnetism', 'transition metal doped graphdiyne magnetic characteristics']
#
# === Iteration 2 ===
# Aggregated 34 unique links from this iteration.
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219
# Fetching content from: https://pubs.acs.org/doi/10.1021/acsami.8b03413
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S2773012322001121
# Fetching content from: https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties
# Fetching content from: https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne
# Fetching content from: https://www.chinesechemsoc.org/doi/10.31635/ccschem.022.202202328
# Fetching content from: https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/
# Fetching content from: https://www.nature.com/articles/s41598-017-11698-9
# Fetching content from: https://www.researchgate.net/figure/The-magnetizations-a-and-dM-dT-b-of-the-Graphdiyne-system-with-mixed-spins-S3-2-and_fig2_371953050
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S1386947721003660
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0927796X24001190
# Fetching content from: https://pubs.acs.org/doi/abs/10.1021/acs.chemmater.3c01551
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00348
# Fetching content from: https://www.jnsam.com/article_199976.html
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/
# Fetching content from: https://www.researchgate.net/publication/262149853_New_materials_graphyne_graphdiyne_graphone_and_graphane_Review_of_properties_synthesis_and_application_in_nanotechnology
# Fetching content from: https://www.jnsam.com/article_199976_6dbdc62971cdb6a27dee14aee5aced6c.pdf
# Fetching content from: https://www.helmholtz-berlin.de/pubbin/news_seite?nid=24109&sprache=en&seitenid=74699
# Fetching content from: https://www.nature.com/articles/s41535-017-0010-2
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940
# Fetching content from: https://www.researchgate.net/publication/356352630_Field_emission_from_two_dimensional_materials_a_quantum_mechanical_model_and_its_application_to_graphene
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevB.87.155441
# Fetching content from: https://ui.adsabs.harvard.edu/abs/2012PhDT.......227C/abstract
# Fetching content from: https://www.nature.com/articles/s41535-022-00435-9
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0925838824039148
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350
# Fetching content from: https://pubmed.ncbi.nlm.nih.gov/37336210/
# Fetching content from: https://www.researchgate.net/publication/356588932_Graphdiyne_doped_with_transition_metal_as_ferromagnetic_semiconductor
# Fetching content from: https://www.researchgate.net/publication/317148310_Electronic_and_magnetic_properties_of_transition_metal_doped_graphyne
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00675
# Fetching content from: https://search.library.albany.edu/discovery/fulldisplay?docid=cdi_proquest_journals_2638770766&context=PC&vid=01SUNY_ALB:01SUNY_ALB&lang=en&search_scope=allthethings&adaptor=Primo%20Central&tab=allthethings&query=sub%2Cexact%2C%20Magnetic%20moment%20%2CAND&mode=advanced&offset=10
# Fetching content from: https://ouci.dntb.gov.ua/en/works/73mzK36l/
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00348: No
# Page usefulness for https://pubs.acs.org/doi/10.1021/acsami.8b03413: No
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00675: No
# Page usefulness for https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne: Yes
# Page usefulness for https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties: No
# Page usefulness for https://www.researchgate.net/publication/356352630_Field_emission_from_two_dimensional_materials_a_quantum_mechanical_model_and_its_application_to_graphene: No
# Page usefulness for https://pubs.acs.org/doi/abs/10.1021/acs.chemmater.3c01551: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/: Yes
# Page usefulness for https://link.aps.org/doi/10.1103/PhysRevB.87.155441: No
# Page usefulness for https://www.researchgate.net/publication/317148310_Electronic_and_magnetic_properties_of_transition_metal_doped_graphyne: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940: Yes
# Page usefulness for https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/: Yes
# Page usefulness for https://www.researchgate.net/figure/The-magnetizations-a-and-dM-dT-b-of-the-Graphdiyne-system-with-mixed-spins-S3-2-and_fig2_371953050: No
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0925838824039148: Yes
# Page usefulness for https://www.chinesechemsoc.org/doi/10.31635/ccschem.022.202202328: No
# Page usefulness for https://ui.adsabs.harvard.edu/abs/2012PhDT.......227C/abstract: No
# Page usefulness for https://www.researchgate.net/publication/356588932_Graphdiyne_doped_with_transition_metal_as_ferromagnetic_semiconductor: No
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0927796X24001190: No
# Page usefulness for https://ouci.dntb.gov.ua/en/works/73mzK36l/: Yes
# Page usefulness for https://www.nature.com/articles/s41598-017-11698-9: Yes
# Page usefulness for https://www.jnsam.com/article_199976.html: Yes
# Page usefulness for https://www.helmholtz-berlin.de/pubbin/news_seite?nid=24109&sprache=en&seitenid=74699: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S1386947721003660: No
# Page usefulness for https://www.jnsam.com/article_199976_6dbdc62971cdb6a27dee14aee5aced6c.pdf: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S2773012322001121: Yes
# Extracted context from https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne (first 200 chars): I apologize, but the provided webpage content appears to be a security verification page and does not contain any substantive information about graphdiyne's magnetic properties. No relevant informatio
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/: Yes
# Page usefulness for https://www.nature.com/articles/s41535-022-00435-9: No
# Page usefulness for https://search.library.albany.edu/discovery/fulldisplay?docid=cdi_proquest_journals_2638770766&context=PC&vid=01SUNY_ALB:01SUNY_ALB&lang=en&search_scope=allthethings&adaptor=Primo%20Central&tab=allthethings&query=sub%2Cexact%2C%20Magnetic%20moment%20%2CAND&mode=advanced&offset=10: No
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/ (first 200 chars): Here are the key details about graphdiyne's magnetism properties from the text:
#
# Graphdiyne can exhibit ferromagnetic properties through strategic doping, particularly with heteroatoms like fluorine.
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940 (first 200 chars): Here are the key findings related to graphdiyne magnetism from the research paper:
#
# Graphdiyne has unique magnetic properties that can be engineered through various methods:
#
# 1. Quantum Mechanical Mod
# Extracted context from https://www.jnsam.com/article_199976.html (first 200 chars): Based on the webpage content, here are the relevant details about graphdiyne's magnetic properties:
#
# Magnetic Properties of Graphdiyne:
# - Exhibits spin half paramagnetic behavior
# - Intrinsic magnetism
# Extracted context from https://www.jnsam.com/article_199976_6dbdc62971cdb6a27dee14aee5aced6c.pdf (first 200 chars): Based on the extracted text, here are the relevant details about graphdiyne's magnetism properties:
#
# Magnetic Properties:
# - Graphdiyne shows spin-paired magnetism, in contrast to graphene which is non
# Extracted context from https://ouci.dntb.gov.ua/en/works/73mzK36l/ (first 200 chars): Graphdiyne magnetic properties when doped with transition metals:
#
# Transition metal doping can induce ferromagnetic and magnetic characteristics in graphdiyne. Key observations include:
#
# 1. Room-tempe
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0925838824039148 (first 200 chars): Here are the key findings on graphdiyne magnetism properties from the research paper:
#
# Magnetic Properties of Transition Metal Doped Graphdiyne:
#
# 1. Pristine graphdiyne exhibits paramagnetic behavior
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/ (first 200 chars): Here are the key findings about graphdiyne's magnetic properties from this research paper:
#
# Magnetic Properties:
# - Graphdiyne can be modified to exhibit different magnetic characteristics by introduci
# Extracted context from https://www.nature.com/articles/s41598-017-11698-9 (first 200 chars): Relevant Context for "graphdiyne magnetism properties":
#
# Key Magnetic Properties of Graphdiyne (GDY):
#
# 1. Pure graphdiyne shows paramagnetism with a saturation moment Ms = 0.51 emu/g at 2 K, arising f
# Page usefulness for https://www.nature.com/articles/s41535-017-0010-2: No
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/ (first 200 chars): Based on the content, here are the relevant details about graphdiyne's magnetism properties:
#
# The document does not provide extensive specific details about graphdiyne's magnetism properties. While th
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350 (first 200 chars): Based on the content, here are the key details about graphdiyne magnetism properties:
#
# Graphdiyne (GDY) was doped with transition metals (Fe, Co, Ni) to introduce ferromagnetic properties. Key finding
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S2773012322001121 (first 200 chars): Here are the key points about graphdiyne's magnetic properties from the document:
#
# Graphdiyne Magnetic Properties:
#
# 1. Magnetic Characteristics:
# - Graphdiyne is a two-dimensional magnetic nanofilm wit
# Page usefulness for https://www.researchgate.net/publication/262149853_New_materials_graphyne_graphdiyne_graphone_and_graphane_Review_of_properties_synthesis_and_application_in_nanotechnology: Yes
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219 (first 200 chars): Based on the content, here are the relevant details about graphdiyne's magnetic properties:
#
# Graphdiyne (GDY) is a unique two-dimensional carbon allotrope with special magnetic characteristics:
#
# 1. Ma
# Page usefulness for https://pubmed.ncbi.nlm.nih.gov/37336210/: Yes
# Extracted context from https://www.researchgate.net/publication/262149853_New_materials_graphyne_graphdiyne_graphone_and_graphane_Review_of_properties_synthesis_and_application_in_nanotechnology (first 200 chars): Based on the content, here are the relevant details about graphdiyne's magnetism properties:
#
# While the document does not provide extensive details specifically about graphdiyne's magnetic properties,
# Extracted context from https://pubmed.ncbi.nlm.nih.gov/37336210/ (first 200 chars): Here are the key details about graphdiyne magnetism properties from the abstract:
#
# The study explores the magnetic properties of graphdiyne (GDY) doped with 5d transition metal atoms through first-pri
# LLM provided new search queries: ['graphdiyne magnetic phase transitions', 'DFT modeling of graphdiyne magnetic properties', 'graphdiyne magnetic anisotropy mechanisms', 'experimental verification of graphdiyne magnetism']
#
# === Iteration 3 ===
# Aggregated 34 unique links from this iteration.
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940
# Fetching content from: https://www.nature.com/articles/s41467-024-49942-2
# Fetching content from: https://www.onlinescientificresearch.com/articles/understanding-magnetic-phase-transitions-in-graphene-and-finding-ce2ge2mg.html
# Fetching content from: https://pubs.acs.org/doi/10.1021/acs.jpclett.6b02437
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevX.13.031015
# Fetching content from: https://arxiv.org/abs/2411.12959
# Fetching content from: https://www.nature.com/articles/s41467-020-16430-2
# Fetching content from: https://iopscience.iop.org/article/10.1088/2053-1583/aa5f2d/meta
# Fetching content from: https://www.researchgate.net/publication/385401203_Transition_Metal_Doping_for_Tailoring_Magnetic_Properties_of_Graphdiyne
# Fetching content from: https://arxiv.org/pdf/2406.12250
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0925963524000499
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2666978123000193
# Fetching content from: https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne
# Fetching content from: https://pubs.acs.org/doi/abs/10.1021/acs.jpcc.6b05265
# Fetching content from: https://www.researchgate.net/publication/266911256_Magnetic_Properties_of_Single_Transition-Metal_Atom_Absorbed_Graphdiyne_and_Graphyne_Sheet_from_DFTU_Calculations
# Fetching content from: https://pubs.rsc.org/en/content/articlehtml/2023/ra/d2ra08296a
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/
# Fetching content from: https://www.chinesechemsoc.org/doi/10.31635/ccschem.022.202202328
# Fetching content from: https://www.nature.com/articles/s41598-017-11698-9
# Fetching content from: https://pubs.acs.org/doi/abs/10.1021/acsami.8b03413
# Fetching content from: https://www.nature.com/articles/srep04014
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219
# Fetching content from: https://pubs.rsc.org/en/content/articlehtml/2022/nr/d2nr01458k
# Fetching content from: https://pubmed.ncbi.nlm.nih.gov/37336210/
# Fetching content from: https://www.researchgate.net/publication/371716480_First_principles_study_on_magnetic_anisotropy_of_5d_transition_metal_doped_graphidiyne
# Fetching content from: https://link.aps.org/doi/10.1103/PhysRevResearch.4.013139
# Fetching content from: https://www.tandfonline.com/doi/full/10.1080/23746149.2018.1432415
# Fetching content from: https://onlinelibrary.wiley.com/doi/abs/10.1002/aelm.202300579
# Fetching content from: https://www.nature.com/articles/s41524-024-01502-4
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848
# Fetching content from: https://link.springer.com/article/10.1007/s40242-021-1350-9
# Fetching content from: https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/
# Fetching content from: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4239502
# Page usefulness for https://www.chinesechemsoc.org/doi/10.31635/ccschem.022.202202328: No
# Page usefulness for https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments: No
# Page usefulness for https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940: Yes
# Page usefulness for https://pubmed.ncbi.nlm.nih.gov/37336210/: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/: Yes
# Page usefulness for https://www.researchgate.net/publication/266911256_Magnetic_Properties_of_Single_Transition-Metal_Atom_Absorbed_Graphdiyne_and_Graphyne_Sheet_from_DFTU_Calculations: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.nature.com/articles/s41467-024-49942-2: No
# Page usefulness for https://arxiv.org/abs/2411.12959: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://iopscience.iop.org/article/10.1088/2053-1583/aa5f2d/meta: No
# Page usefulness for https://link.springer.com/article/10.1007/s40242-021-1350-9: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0925963524000499: Yes
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://onlinelibrary.wiley.com/doi/abs/10.1002/aelm.202300579: No
# Page usefulness for https://pubs.acs.org/doi/10.1021/acs.jpclett.6b02437: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://link.aps.org/doi/10.1103/PhysRevX.13.031015: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/: Yes
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.tandfonline.com/doi/full/10.1080/23746149.2018.1432415: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://arxiv.org/pdf/2406.12250: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.onlinescientificresearch.com/articles/understanding-magnetic-phase-transitions-in-graphene-and-finding-ce2ge2mg.html: No
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848: Yes
# Page usefulness for https://www.nature.com/articles/s41598-017-11698-9: Yes
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.researchgate.net/publication/371716480_First_principles_study_on_magnetic_anisotropy_of_5d_transition_metal_doped_graphidiyne: Yes
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://pubs.acs.org/doi/abs/10.1021/acsami.8b03413: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.researchgate.net/publication/385401203_Transition_Metal_Doping_for_Tailoring_Magnetic_Properties_of_Graphdiyne: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://pubs.rsc.org/en/content/articlehtml/2022/nr/d2nr01458k: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://link.aps.org/doi/10.1103/PhysRevResearch.4.013139: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.nature.com/articles/s41524-024-01502-4: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://pubs.rsc.org/en/content/articlehtml/2023/ra/d2ra08296a: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://pubs.acs.org/doi/abs/10.1021/acs.jpcc.6b05265: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S2666978123000193: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://papers.ssrn.com/sol3/papers.cfm?abstract_id=4239502: No
# Extracted context from https://pubmed.ncbi.nlm.nih.gov/37336210/ (first 200 chars): The research paper discusses the magnetic properties of graphdiyne (GDY) doped with 5d transition metal atoms. Key findings include:
#
# 1. Transition metal atoms can be stably embedded in the triangular
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/ (first 200 chars): Relevant Information on Graphdiyne Magnetism Properties:
#
# Graphdiyne is a carbon semiconductor material with potential for magnetic and electronic applications. Key magnetic properties include:
#
# 1. Ma
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.nature.com/articles/s41467-020-16430-2: No
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S1386947721002940 (first 200 chars): Based on the content, here are the key findings about graphdiyne magnetism properties:
#
# Graphdiyne is a two-dimensional carbon material with unique magnetic characteristics:
#
# 1. The magnetic propertie
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0927025621003219 (first 200 chars): Here are the key details about graphdiyne's magnetic properties from the document:
#
# Magnetic Characteristics:
# - Graphdiyne (GDY) can exhibit antiferromagnetic behavior with spin-half
# - Hydroxyl groups
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# Page usefulness for https://www.nature.com/articles/srep04014: No
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
# LLM did not provide any new search queries. Ending the loop.
#
# Generating final report...
# OpenRouter API error: 402 - {"error":{"message":"Insufficient credits. Add more using https://openrouter.ai/credits","code":402}}
#
# ==== FINAL REPORT ====
#
# None
