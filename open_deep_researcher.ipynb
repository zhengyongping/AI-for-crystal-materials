# %% [markdown]
# <a href="https://colab.research.google.com/github/zhengyongping/AI-for-crystal-materials/blob/main/open_deep_researcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)

# %%
import asyncio
import aiohttp
import json

# =======================
# Configuration Constants
# =======================
OPENROUTER_API_KEY = "sk-gnllVBKmkYfZ3EBEF5D268E758924e5a938d8b034109F8A1" # Replace with your OpenRouter API key
SERPAPI_API_KEY = "8f34c7ccffc310cf3564a988c10a0c4e58962db30b921a751f6f39f4ad7e9a2a" # Replace with your SERPAPI API key
JINA_API_KEY = "jina_fac22ed9480b4958ab34e85b443f5da6DNsbdW1C3Jz6383otpRGN1aMY3w3" # Replace with your JINA API key

# Endpoints
OPENROUTER_URL = "https://xiaoai.plus/v1/chat/completions"
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_MODEL = "gpt-4o-mini"


# ============================
# Asynchronous Helper Functions
# ============================

async def call_openrouter_async(session, messages, model=DEFAULT_MODEL):
    """
    Asynchronously call the OpenRouter chat completion API with the provided messages.
    Returns the content of the assistant’s reply.
    """
    headers = {
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
        "X-Title": "OpenDeepResearcher, by Matt Shumer",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": messages
    }
    try:
        async with session.post(OPENROUTER_URL, headers=headers, json=payload) as resp:
            if resp.status == 200:
                result = await resp.json()
                try:
                    return result['choices'][0]['message']['content']
                except (KeyError, IndexError) as e:
                    print("Unexpected OpenRouter response structure:", result)
                    return None
            else:
                text = await resp.text()
                print(f"OpenRouter API error: {resp.status} - {text}")
                return None
    except Exception as e:
        print("Error calling OpenRouter:", e)
        return None


async def generate_search_queries_async(session, user_query):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Query: {user_query}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        try:
            # Expect exactly a Python list (e.g., "['query1', 'query2']")
            search_queries = eval(response)
            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google"
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical research evaluator. Given the user's query and the content of a webpage, "
        "determine if the webpage contains information relevant and useful for addressing the query. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of research relevance."},
        {"role": "user", "content": f"User Query: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the original query, the search query used, and the page content,
    have the LLM extract all information relevant for answering the query.
    """
    prompt = (
        "You are an expert information extractor. Given the user's query, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant to answering the user's query. "
        "Return only the relevant context as plain text without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant information."},
        {"role": "user", "content": f"User Query: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_query, previous_search_queries, all_contexts):
    """
    Based on the original query, the previously used search queries, and all the extracted contexts,
    ask the LLM whether additional search queries are needed. If yes, return a Python list of up to four queries;
    if the LLM thinks research is complete, it should return "<done>".
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an analytical research assistant. Based on the original query, the search queries performed so far, "
        "and the extracted contexts from webpages, determine if further research is needed. "
        "If further research is needed, provide up to four new search queries as a Python list (for example, "
        "['new query1', 'new query2']). If you believe no further research is needed, respond with exactly <done>."
        "\nOutput only a Python list or the token <done> without any additional text."
    )
    messages = [
        {"role": "system", "content": "You are a systematic research planner."},
        {"role": "user", "content": f"User Query: {user_query}\nPrevious Search Queries: {previous_search_queries}\n\nExtracted Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    response = await call_openrouter_async(session, messages)
    if response:
        cleaned = response.strip()
        if cleaned == "<done>":
            return "<done>"
        try:
            new_queries = eval(cleaned)
            if isinstance(new_queries, list):
                return new_queries
            else:
                print("LLM did not return a list for new search queries. Response:", response)
                return []
        except Exception as e:
            print("Error parsing new search queries:", e, "\nResponse:", response)
            return []
    return []


async def generate_final_report_async(session, user_query, all_contexts):
    """
    Generate the final comprehensive report using all gathered contexts.
    """
    context_combined = "\n".join(all_contexts)
    prompt = (
        "You are an expert researcher and report writer. Based on the gathered contexts below and the original query, "
        "write a comprehensive, well-structured, and detailed report that addresses the query thoroughly. "
        "Include all relevant insights and conclusions without extraneous commentary."
    )
    messages = [
        {"role": "system", "content": "You are a skilled report writer."},
        {"role": "user", "content": f"User Query: {user_query}\n\nGathered Relevant Contexts:\n{context_combined}\n\n{prompt}"}
    ]
    report = await call_openrouter_async(session, messages)
    return report


async def process_link(session, link, user_query, search_query):
    """
    Process a single link: fetch its content, judge its usefulness, and if useful, extract the relevant context.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_query, page_text)
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_query, search_query, page_text)
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    user_query = input("Enter your research query/topic: ").strip()
    iter_limit_input = input("Enter maximum number of iterations (default 10): ").strip()
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 10

    aggregated_contexts = []    # All useful contexts from every iteration
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_query)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit:
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts = []

            # For each search query, perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            # Map each unique link to the search query that produced it.
            unique_links = {}
            for idx, links in enumerate(search_results):
                query = new_search_queries[idx]
                for link in links:
                    if link not in unique_links:
                        unique_links[link] = query

            print(f"Aggregated {len(unique_links)} unique links from this iteration.")

            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = [
                process_link(session, link, user_query, unique_links[link])
                for link in unique_links
            ]
            link_results = await asyncio.gather(*link_tasks)

            # Collect non-None contexts.
            for res in link_results:
                if res:
                    iteration_contexts.append(res)

            if iteration_contexts:
                aggregated_contexts.extend(iteration_contexts)
            else:
                print("No useful contexts were found in this iteration.")

            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            new_search_queries = await get_new_search_queries_async(session, user_query, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break

            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_query, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# Enter your research query/topic: graphdiyne magnetism properties
# Enter maximum number of iterations (default 10): 10
#
# === Iteration 1 ===
# Aggregated 22 unique links from this iteration.
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0925838824039148
# Fetching content from: https://pubs.acs.org/doi/10.1021/acsami.8b03413
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S0927025621003219
# Fetching content from: https://pubs.acs.org/doi/10.1021/jp307408u
# Fetching content from: https://link.springer.com/article/10.1007/s12648-023-02798-6
# Fetching content from: https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/
# Fetching content from: https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne
# Fetching content from: https://www.nature.com/articles/s41598-017-11698-9
# Fetching content from: https://link.springer.com/article/10.1007/s40242-021-1350-9
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00675
# Fetching content from: https://pubs.acs.org/doi/10.1021/acscentsci.0c00348
# Fetching content from: https://onlinelibrary.wiley.com/doi/abs/10.1002/9783527828470.ch8
# Fetching content from: https://www.sciencedirect.com/science/article/pii/S2772571524000585
# Fetching content from: https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/
# Fetching content from: https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments
# Fetching content from: https://www.semanticscholar.org/paper/Graphdiyne%3A-synthesis%2C-properties%2C-and-Gao-Liu/bf53fda43e5a7db0005e9141f60470c2ec1ef2f3
# Fetching content from: https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/
# Fetching content from: https://pubs.acs.org/doi/abs/10.1021/acsami.8b03413
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00675: No
# Page usefulness for https://pubs.acs.org/doi/10.1021/acsami.8b03413: No
# Page usefulness for https://pubs.aip.org/aip/apl/article/111/3/033101/35362/Intrinsic-magnetism-of-graphdiyne: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/: Yes
# Page usefulness for https://link.springer.com/article/10.1007/s40242-021-1350-9: Yes
# Page usefulness for https://pubs.acs.org/doi/10.1021/jp307408u: No
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848: Yes
# Page usefulness for https://pubs.acs.org/doi/10.1021/acscentsci.0c00348: No
# Page usefulness for https://pubs.acs.org/doi/abs/10.1021/acsami.8b03413: No
# Page usefulness for https://www.researchgate.net/publication/324812800_A_Review_of_the_Electronic_Optical_and_Magnetic_Properties_of_Graphdiyne_From_Theories_to_Experiments: No
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0927025621003219: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S0925838824039148: Yes
# Extracted context from https://link.springer.com/article/10.1007/s40242-021-1350-9 (first 200 chars): I'm sorry, but there doesn't seem to be any specific information regarding the magnetic properties of graphdiyne in the content provided.
# Page usefulness for https://www.nature.com/articles/s41598-017-11698-9: Yes
# Page usefulness for https://www.nature.com/research-intelligence/graphdiyne-and-its-electronic-properties: No
# Page usefulness for https://link.springer.com/article/10.1007/s12648-023-02798-6: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/: Yes
# Page usefulness for https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/: Yes
# Page usefulness for https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350: Yes
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0925838822050848 (first 200 chars): Graphdiyne (GDY) is considered a potential spintronics material due to its unique electronic and magnetic properties. The introduction of ferromagnetic order into graphdiyne remains a significant chal
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0927025621003219 (first 200 chars): Magnetic and thermodynamic properties of a monolayer graphdiyne-like were examined using an Ising model described by effective-field theory with correlations. Key findings include:
#
# - Mixed spin Ising
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318061/ (first 200 chars): To date, the realization of ferromagnetism in two-dimensional carbon semiconductors containing only sp electrons has remained a challenge for spintronics. The study utilizes an atomic-level functional
# Extracted context from https://www.nature.com/articles/s41598-017-11698-9 (first 200 chars): The magnetic properties of graphdiyne (GDY) are explored, highlighting its potential in spintronics. Pure graphdiyne exhibits typical paramagnetism with a saturation moment of 0.51 emu/g at 2 K, attri
# Page usefulness for https://www.sciencedirect.com/science/article/pii/S2772571524000585: No
# Page usefulness for https://www.semanticscholar.org/paper/Graphdiyne%3A-synthesis%2C-properties%2C-and-Gao-Liu/bf53fda43e5a7db0005e9141f60470c2ec1ef2f3: Yes
# Extracted context from https://link.springer.com/article/10.1007/s12648-023-02798-6 (first 200 chars): In this work, using the Monte Carlo study, we illustrated the magnetic and magnetocaloric properties of the L-graphdiyne system with mixed 5/2 and 3/2 spins. We obtain magnetizations and magnetic susc
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC3998860/ (first 200 chars): Graphdiyne is a two-dimensional carbon allotrope with unique electronic structures and properties. While specific details on its magnetic properties are less pronounced compared to other variants like
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC8469384/ (first 200 chars): Doping and its consequences on the electronic features and magnetism of graphynes (GYs) are reviewed. Synthetic strategies for graphynes are discussed, including heteroatom doping and methods to modul
# Extracted context from https://www.sciencedirect.com/science/article/pii/S0925838824039148 (first 200 chars): Graphdiyne (GDY) exhibits paramagnetic behavior with a saturation moment of 0.51 emu·g⁻¹ at 2 K. Transition metal (TM) doping, particularly with Fe, Co, and Ni, has been shown to enhance the electroma
# Page usefulness for https://onlinelibrary.wiley.com/doi/abs/10.1002/9783527828470.ch8: No
# Extracted context from https://www.sciencedirect.com/science/article/abs/pii/S0008622321011350 (first 200 chars): Graphdiyne doped with transition metal as ferromagnetic semiconductor - ScienceDirect
#
# Abstract:
# Long-range ferromagnetic ordering in semiconductors has become an attractive research hotspot due to it
# Extracted context from https://www.semanticscholar.org/paper/Graphdiyne%3A-synthesis%2C-properties%2C-and-Gao-Liu/bf53fda43e5a7db0005e9141f60470c2ec1ef2f3 (first 200 chars): Graphdiyne (GDY) is a novel two-dimensional (2D) carbon allotrope with unique properties that make it a subject of interest in the field of materials science. The synthesis of graphdiyne and its deriv
# Extracted context from https://pmc.ncbi.nlm.nih.gov/articles/PMC7318078/ (first 200 chars): The rise and prosperity of graphdiyne have enriched the family of carbon materials. As a carbon semiconductor material, its direct band gap, highly conjugated structure, and impressive intrinsic mobil
# LLM indicated that no further research is needed.
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# # Report on the Magnetism Properties of Graphdiyne
#
# ## Introduction
#
# Graphdiyne (GDY) is a novel two-dimensional carbon allotrope that has garnered extensive attention in material science and spintronics due to its unique electronic and magnetic properties. Originally proposed in 1997, and synthesized in its γ-variant in 2010, GDY features a distinct carbon matrix characterized by sp-hybridization, which contributes to its electronic properties and potential applications in various technological fields such as energy conversion and storage. This report compiles current findings on the magnetism properties of graphdiyne, with a focus on its intrinsic magnetic behaviors and the effects of doping and structural modifications.
#
# ## Intrinsic Magnetic Properties
#
# Pristine graphdiyne demonstrates paramagnetic behavior, characterized by a saturation moment of 0.51 emu·g⁻¹ at 2 K. This paramagnetism is attributed to the unique arrangements of carbon atoms that disrupt delocalized π-electronic systems, facilitating the emergence of local magnetic moments. Initial theoretical models indicated that intrinsic structural features of graphdiyne could give rise to magnetic phenomena, suggesting the potential for engineering its characteristics through material manipulation.
#
# ## Transition Metal Doping
#
# ### Doping with Transition Metals
#
# Transition metal (TM) doping, particularly with iron (Fe), cobalt (Co), and nickel (Ni), has been identified as an effective strategy to induce ferromagnetism in graphdiyne. Experimental investigations have shown that:
#
# - **Fe-Doped Graphdiyne (Fe-GDY)**: Exhibits robust room-temperature ferromagnetism, with a saturation magnetization of 2.86 emu·g⁻¹. Notable magnetic behavior was observed, characterized by well-defined hysteresis loops at both 5 K and 300 K. DFT calculations indicated a kagome lattice structure formed by the doped Fe atoms, which enhances the material’s magnetic properties.
#
# - **Co-Doped Graphdiyne (Co-GDY)**: Demonstrates significant local magnetic moments, yielding a Curie temperature above room temperature (approximately 350 K) and a coercive field of 78 Oe at 300 K. These findings emphasize the material's potential for spintronic applications.
#
# - **Ni-Doped Graphdiyne (Ni-GDY)**: Exhibited a saturation magnetization of 1.04 emu·g⁻¹ at 5 K, indicating a lesser magnetic response compared to its Fe and Co counterparts.
#
# ### Synthesis and Engineering Methods
#
# Recent advancements in synthesis techniques have further propelled the development of ferromagnetic graphdiyne. The improvement of synthesis methods, such as liquid-liquid interface synthesis, allows for controlled doping, enabling homogenous integration of transition metals into the GDY structure. This level of control is critical for achieving desired magnetic behaviors while maintaining excellent electronic properties.
#
# Post-synthesis modifications, such as annealing, have also been explored. For instance, Co-GDY annealed at 500°C exhibited optimal room-temperature ferromagnetism with a saturation magnetization of 0.26 emu·g⁻¹, underscoring the influence of thermal treatments on magnetic characteristics.
#
# ## Other Doping Strategies
#
# In addition to transition metal doping, the introduction of light elements like nitrogen and halogens has been shown to significantly impact the magnetic properties of GDY:
#
# - **Nitrogen Doping**: The incorporation of nitrogen atoms enhances the paramagnetism of graphdiyne, increasing the local magnetic moments due to changes in the density of states. Therefore, nitrogen-doped GDY (N-GDY) emerges as a promising candidate for exhibits improved magnetic performance.
#
# - **Fluorine Doping**: Specifically, fluorine-doped graphdiyne (FsGDY) has been noted for its remarkable ferromagnetic characteristics. Fluorine functionalization enhances charge transfer properties while establishing a ferromagnetic coupling at temperatures below 16 K. The mobility of FsGDY reaches up to 320 cm²/V·s, reinforcing its potential for spintronic applications.
#
# ## Theoretical Modeling
#
# Theoretical frameworks, including density functional theory (DFT) and Monte Carlo simulations, have been instrumental in understanding the underlying magnetic mechanisms within graphdiyne. These studies have revealed how various structural configurations, such as the kagome lattice resulting from transition metal doping, contribute to electronic properties and ferromagnetism.
#
# Research employing the Ising model has further illustrated the magnetic and thermodynamic properties of graphdiyne-like structures, indicating complex behaviors such as mixed spin interactions and compensation phenomena.
#
# ## Conclusion
#
# Graphdiyne presents a compelling case as a 2D carbon semiconductor with versatile magnetic properties that can be tailored through doping and engineering methods. Intrinsic paramagnetism can be effectively transformed into robust ferromagnetism via transition metal doping and careful material modifications. With enhanced magnetic behaviors observed in TM-doped and fluorine-modified versions, graphdiyne shows significant promise for applications in spintronics and beyond. Continued exploration of synthesis methods and structural modifications will be vital in unlocking the full potential of graphdiyne as a functional material in future technologies.
